# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np

# %%
noises = [0.0, 0.04, 0.06, 0.08, 0.12, 0.15, 0.18, 0.24, 0.30]

er_gcn = np.array([0.9886, 0.9826, 0.92, 0.807, 0.5152, 0.3578, 0.25, 0.117, 0.0708])
er_gat = np.array([0.999,0.997, 0.9839, 0.931, 0.6615, 0.47, 0.32, 0.14, 0.078])

pcqm4mv2_gcn = np.array([0.91,0.893, 0.845, 0.816, 0.723, 0.645, 0.627, 0.529, 0.449])
pcqm4mv2_gat = np.array([0.909, 0.886, 0.8479, 0.8197, 0.7359, 0.668, 0.6455, 0.549, 0.471])

ogbn_gcn = np.array([0.729, 0.7170, 0.639, 0.552, 0.412, 0.337, 0.279, 0.1922, 0.136])
ogbn_gat = np.array([0.735, 0.725, 0.66, 0.582, 0.451, 0.383, 0.3118, 0.218, 0.156])

aqsol_gcn = np.array([0.798, 0.79, 0.74, 0.70, 0.607, 0.555, 0.49, 0.41, 0.34])
aqsol_gat = np.array([0.791, 0.785, 0.746, 0.715, 0.6345, 0.585, 0.518, 0.439, 0.3656]) 

corafull_gcn = np.array([0.799, 0.791, 0.737, 0.667, 0.5617, 0.4857, 0.4038, 0.292, 0.2120])
corafull_gat = np.array([0.801, 0.7980, 0.75, 0.688, 0.595, 0.52216, 0.4399, 0.3238, 0.227])

# %%
fig, ax = plt.subplots()
ax.plot(noises, er_gat - er_gcn, color="black")
plt.xlabel(r"$\eta$ (noise amount)")
plt.ylabel("Difference in Accuracy")
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(noises, pcqm4mv2_gat - pcqm4mv2_gcn, color="black")
plt.xlabel(r"$\eta$ (noise amount)")
plt.ylabel("Difference in Accuracy")
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(noises, ogbn_gat - ogbn_gcn, color="black")
plt.xlabel(r"$\eta$ (noise amount)")
plt.ylabel("Difference in Accuracy")
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(noises, aqsol_gat - aqsol_gcn, color="black")
plt.xlabel(r"$\eta$ (noise amount)")
plt.ylabel("Difference in Accuracy")
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(noises, corafull_gat - corafull_gcn, color="black")
plt.xlabel(r"$\eta$ (noise amount)")
plt.ylabel("Difference in Accuracy")
ax.xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(16, 10))

# Set the space between plots to avoid overlap
plt.subplots_adjust(hspace=0.4, wspace=0.2)

# Plotting on the first row (3 plots)
axs[0, 0].plot(noises, er_gat - er_gcn, color='black')  # Example plot
axs[0, 0].set_title('Erdös-Rényi')
axs[0, 0].xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[0, 0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[0, 0].set_xlabel(r"$\eta$ (noise amount)")
axs[0, 0].set_ylabel("Difference in Accuracy")

axs[0, 1].plot(noises, ogbn_gat - ogbn_gcn, color='black')  # Example plot
axs[0, 1].set_title('OGBN-Arxiv')
axs[0, 1].xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[0, 1].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[0, 1].set_xlabel(r"$\eta$ (noise amount)")
axs[0, 1].set_ylabel("Difference in Accuracy")


axs[1, 0].plot(noises, corafull_gat - corafull_gcn, color='black')  # Example plot
axs[1, 0].set_title('CoraFull')
axs[1, 0].xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[1, 0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[1, 0].set_xlabel(r"$\eta$ (noise amount)")
axs[1, 0].set_ylabel("Difference in Accuracy")

# Plotting on the first row (3 plots)
axs[1, 1].plot(noises, aqsol_gat - aqsol_gcn, color='black')  # Example plot
axs[1, 1].set_title('AQSOL')
axs[1, 1].xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[1, 1].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[1, 1].set_xlabel(r"$\eta$ (noise amount)")
axs[1, 1].set_ylabel("Difference in Accuracy")

axs[2, 0].plot(noises, pcqm4mv2_gat - pcqm4mv2_gcn, color='black')  # Example plot
axs[2, 0].set_title('PCQM4Mv2')
axs[2, 0].xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[2, 0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[2, 0].set_xlabel(r"$\eta$ (noise amount)")
axs[2, 0].set_ylabel("Difference in Accuracy")

# Hide the third plot in the second row (leave it blank)
axs[2, 1].axis('off')

# Display the plot
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(16, 10))

# Set the space between plots to avoid overlap
plt.subplots_adjust(hspace=0.4, wspace=0.2)

# Plotting on the first row (3 plots)
axs[0, 0].plot(noises, er_gat, '-', color='black', label="GAT")  # Example plot
axs[0, 0].plot(noises, er_gcn, '--', color='black', label="GCN")  # Example plot
axs[0,0].legend(loc="upper right")
axs[0, 0].set_title('Erdös-Rényi')
axs[0, 0].xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[0, 0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[0, 0].set_xlabel(r"$\eta$ (noise amount)")
axs[0, 0].set_ylabel("Accuracy")


axs[0, 1].plot(noises, ogbn_gat, '-', color='black', label="GAT")  # Example plot
axs[0, 1].plot(noises, ogbn_gcn, '--', color='black', label="GCN")  # Example plot
axs[0, 1].legend(loc="upper right")
axs[0, 1].set_title('OGBN-Arxiv')
axs[0, 1].xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[0, 1].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[0, 1].set_xlabel(r"$\eta$ (noise amount)")
axs[0, 1].set_ylabel("Accuracy")


axs[1, 0].plot(noises, corafull_gat, '-', color='black', label="GAT")  # Example plot
axs[1, 0].plot(noises, corafull_gcn, '--', color='black', label="GCN")  # Example plot
axs[1, 0].legend(loc="upper right")
axs[1, 0].set_title('CoraFull')
axs[1, 0].xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[1, 0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[1, 0].set_xlabel(r"$\eta$ (noise amount)")
axs[1, 0].set_ylabel(" Accuracy")

# Plotting on the first row (3 plots)
axs[1, 1].plot(noises, aqsol_gat, '-', color='black', label="GAT")  # Example plot
axs[1, 1].plot(noises, aqsol_gcn, '--', color='black', label="GCN")  # Example plot
axs[1, 1].legend(loc="upper right")
axs[1, 1].set_title('AQSOL')
axs[1, 1].xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[1, 1].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[1, 1].set_xlabel(r"$\eta$ (noise amount)")
axs[1, 1].set_ylabel("Accuracy")

axs[2, 0].plot(noises, pcqm4mv2_gat, '-', color='black', label="GAT")  # Example plot
axs[2, 0].plot(noises, pcqm4mv2_gcn, '--', color='black', label="GCN")  # Example plot
axs[2,0].legend(loc="upper right")
axs[2, 0].set_title('PCQM4Mv2')
axs[2, 0].xaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[2, 0].yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
axs[2, 0].set_xlabel(r"$\eta$ (noise amount)")
axs[2, 0].set_ylabel("Accuracy")

# Hide the third plot in the second row (leave it blank)
axs[2, 1].axis('off')

# Display the plot
plt.show()
