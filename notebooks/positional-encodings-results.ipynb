# %%
import pandas

# %%
paths = [f"../results-pe/run-{i}.csv" for i in range(1,8)]
dataframes = [pandas.read_csv(path) for path in paths]
df = pandas.concat(dataframes)
median = df[["Name", "loss/train"]].groupby("Name").mean()
std = df[["Name", "loss/train"]].groupby("Name").std()
std
# Out:
#                   loss/train
# Name
# GAT                 0.016536
# GCN                 0.008577
# Transformer         0.021786
# Transformer-GAPE    0.031392
# Transformer-LAPE    0.033945
